# %%
# %load_ext autoreload
# %autoreload 2
import copper
import numpy as np
import pandas as pd
copper.project.path = '..'

# %%
train = copper.load('train.ds')

# %%
hist = train.plot('hist', 'votes_useful', bins=100, legend=False, ret_list=True)

# %%
hist.head(7)
# Out:
# 0    0.0 - 2.35: 179974
# 1     2.4 - 4.71: 21666
# 2      4.7 - 7.06: 8476
# 3      7.1 - 9.41: 2099
# 4     9.4 - 11.76: 1149
# 5     11.8 - 14.12: 976
# 6     14.1 - 16.47: 328

# %%
train.plot('scatter', 'pos', 'votes_useful', reg=True, alpha=0.1)

# %%
train.plot('scatter', 'stars', 'votes_useful', reg=True, alpha=0.1)

# %%
train[['pos', 'votes_useful']].describe()
# Out:
#                 pos   votes_useful
# count  2.151650e+05  215165.000000
# mean   5.479538e-01       1.389129
# std    3.227651e-01       2.239207
# min    9.857694e-12       0.000000
# 25%    2.705123e-01       0.000000
# 50%    5.677813e-01       1.000000
# 75%    8.497391e-01       2.000000
# max    1.000000e+00     120.000000
